# %%
import pandas as pd
policeData = pd.read_csv("PoliceBlotter.csv")
policeData.head()
# Out:
#        _id         PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0  3182043  324785812  23176351         29  2023-11-06T10:00:00
# 1  3182044  324235775  23171535         27  2023-10-28T05:00:00
# 2  3182045  324798988  23176386         10  2023-11-06T10:30:00
# 3  3182046  324799806  23176355          0  2023-11-06T11:00:00
# 4  3182047  324806932  23176425          6  2023-11-05T22:30:00
#
#                                 INCIDENTLOCATION CLEAREDFLAG  \
# 0   1500 Block Garfield Ave Pittsburgh, PA 15212           N
# 1  7200 Block Monticello St Pittsburgh, PA 15208           N
# 2         100 Block Ruth St Pittsburgh, PA 15211           Y
# 3   7300 Block Hamilton Ave Pittsburgh, PA 15208           Y
# 4        700 Block Penn Ave Pittsburgh, PA 15219           N
#
#         INCIDENTNEIGHBORHOOD INCIDENTZONE           INCIDENTHIERARCHYDESC  \
# 0         Central North Side            1             RUNAWAYS - JUVENILE
# ...

# %% [markdown]
# Kiro Shaker
#
# Explanation: I took the data from the community facilities dataset from wprdc and counted the number of community facilities per neighborhood and listed them out from least to greatest.
#
# Personal Metric: My personal metric considered a higher number of community facilities as a sign that the neighborhood is better to buy a house to raise a family in.
#
# Conclusion: According to my personal metric, the best neighborhood is Perry South leading all other neighborhoods with 27 community facilities.

# %%
# imports pandas and sets park to the file contents
import pandas as pd
facilities = pd.read_csv("community-facilities-dataset.csv")


# creates a dictionary
dictionary = dict()

# iterates through the rows of neighborhood column
for index, row in park.iterrows():
    name = row["neighborhood"]
    
    # if new neighborhood is seen for the first time, it gets added to the dictionary as a key
    if name not in dictionary:
        dictionary[name] = 1
    # if duplicate neighborhood is seen, a value is added
    else:
        dictionary[name] +=1

# this sorts the dictioanry in decending order based on the value assigned to the key
sortedDictionary = sorted(dictionary, key = dictionary.get, reverse = True)
# for every key in the sorted version of the dictionary it prints out the key and the value
for key in sortedDictionary:
    print(key, dictionary[key])
# Out:
# Perry South 27
# Homewood North 23
# Homewood South 23
# Homewood West 23
# Central North Side 21
# Manchester 19
# Perry North 19
# Shadland Halls Grove 19
# Squirrel Hill - North of Forbes 19
# Squirrel Hill - South of Forbes 19
# Allegheny Center 17
# Brighton Heights 16
# Garfield 16
# Allegheny West 15
# California Ave 15
# Hazelwood-Glenwood-Glen Hazel 15
# East Liberty 14
# Mount Washington - Duquesne Heights 14
# Bloomfield 13
# Larimer 13
# Lower Lawrenceville 13
# Northview Heights 13
# Southside Flats 13
# The Strip 13
# Troy Hill 13
# Upper Lawrenceville 13
# Beechview 12
# Harpen Hilltop 12
# Lawrenceville 12
# Lower Oakland 12
# Point Breeze 12
# Spring Hill 12
# Brookline 11
# Carrick 11
# East North Side 11
# Highland Park 11
# Lincoln-Leminton-Belmar 11
# Middle Hill 11
# South Oakland 11
# The Bluff 11
# Crafton Heights - Westwood - Oakwood 10
# Greenfield 10
# Polish Hill 10
# Shadyside 10
# Terrace Village 10
# Bedford Dwellings 9
# East Brookline - Overbrook 9
# ...
